# %% [markdown]
# # Tweets of @megmfurr

# %%
# import modules
import time
import os
import tweepy
from tweepy import Stream
from tweepy import OAuthHandler
from tweepy.streaming import StreamListener
import csv
import pandas
from datetime import datetime,date
import matplotlib

# %%
# keys & secrets
consumer_key = '6WkmbplsZlk5vtoRB9ksuOf53'
consumer_secret = 'EbwC3fQeGncUWH3ubIPC5tcRPbKUlO1X8bVsUKLHe2vRb7j7Ra'
access_key = '3051436930-GMhQr6Mr5AWMHl3eJhME2DHnniP9nGfBLTLuxqF'
access_secret = 'WHoOBdVnFHkPpburc7eaIg7qxzKQgrpvsIms9u3RwHgkw'

# %%
# get_all_tweets def
def get_all_tweets(screen_name):
    #Twitter only allows access to a users most recent 3240 tweets with this method
    
    #authorize twitter, initialize tweepy
    auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_key, access_secret)
    api = tweepy.API(auth)
    
    #initialize a list to hold all the tweepy Tweets
    alltweets = []
    
    #make initial request for most recent tweets (200 is the maximum allowed count)
    new_tweets = api.user_timeline(screen_name = screen_name,count=200)
    
    #save most recent tweets
    alltweets.extend(new_tweets)
    
    #save the id of the oldest tweet less one
    oldest = alltweets[-1].id - 1
    
    #keep grabbing tweets until there are no tweets left to grab
    while len(new_tweets) > 0:
        print "getting tweets before %s" % (oldest)
        
        #all subsiquent requests use the max_id param to prevent duplicates
        new_tweets = api.user_timeline(screen_name = screen_name,count=200,max_id=oldest)
        
        #save most recent tweets
        alltweets.extend(new_tweets)
        
        #update the id of the oldest tweet less one
        oldest = alltweets[-1].id - 1
        
        print "...%s tweets downloaded so far" % (len(alltweets))
        
        #transform the tweepy tweets into a 2D array that will populate the csv	
        outtweets = [[tweet.id_str, tweet.created_at, tweet.text.encode("utf-8")] for tweet in alltweets]
        
        #write the csv
        with open('%s_tweets.csv' % screen_name, 'wb') as f:
            writer = csv.writer(f)
            writer.writerow(["id","created_at","text"])
            writer.writerows(outtweets)
        pass

# %%
# getting tweets
if __name__ == '__main__':
    #pass in the username of the account you want to download
    get_all_tweets("@megmfurr")
# Out:
# getting tweets before 899433669663784959
# ...398 tweets downloaded so far
# getting tweets before 865605302195896319
# ...598 tweets downloaded so far
# getting tweets before 835847120246685696
# ...798 tweets downloaded so far
# getting tweets before 817748337403301887
# ...998 tweets downloaded so far
# getting tweets before 804862664170213376
# ...1198 tweets downloaded so far
# getting tweets before 789892023025332223
# ...1398 tweets downloaded so far
# getting tweets before 770407005165068287
# ...1598 tweets downloaded so far
# getting tweets before 754506647272390655
# ...1798 tweets downloaded so far
# getting tweets before 739182998889758719
# ...1995 tweets downloaded so far
# getting tweets before 714182599468421119
# ...2191 tweets downloaded so far
# getting tweets before 688549620071444479
# ...2390 tweets downloaded so far
# getting tweets before 615692388716167167
# ...2528 tweets downloaded so far
# getting tweets before 569310957404590079
# ...2528 tweets downloaded so far

# %%
# save csv file as megmfurr_tweets
megmfurr_tweets = pandas.read_csv('@megmfurr_tweets.csv')
megmfurr_tweets
# Out:
#                       id           created_at  \
# 0     942072151733043202  2017-12-16 16:41:18
# 1     942029972377661442  2017-12-16 13:53:42
# 2     941728012705370112  2017-12-15 17:53:49
# 3     941462275436830721  2017-12-15 00:17:52
# 4     941448227047559169  2017-12-14 23:22:03
# 5     940655914419392512  2017-12-12 18:53:41
# 6     940560045477191681  2017-12-12 12:32:44
# 7     940426211091714048  2017-12-12 03:40:55
# 8     940416916216340481  2017-12-12 03:03:59
# 9     940050662519218177  2017-12-11 02:48:37
# 10    940044054624051200  2017-12-11 02:22:22
# 11    940043253436465153  2017-12-11 02:19:11
# 12    940043230132846592  2017-12-11 02:19:05
# 13    939991435356639234  2017-12-10 22:53:17
# 14    939984185967685632  2017-12-10 22:24:28
# 15    939692346194780160  2017-12-10 03:04:48
# 16    939592085879099392  2017-12-09 20:26:24
# 17    939579816633929729  2017-12-09 19:37:39
# 18    939505718834749441  2017-12-09 14:43:13
# 19    939217296807153665  2017-12-08 19:37:08
# 20    938756272450568197  2017-12-07 13:05:11
# 21    938210458397499392  2017-12-06 00:56:19
# 22    938129656888397825  2017-12-05 19:35:14
# 24    RT @qz: The most important skill for 21st-cent...
# 25    RT @riblah: Heartbreaking and maddening. Revis...
# 26    RT @gracekillelea: The hidden victim of sexual...
# 27    RT @GlblCtzn: Most men don't talk about period...
# 28    RT @kimmaicutler: Why can't journalists from B...
# 29    RT @KirkDBorne: #BigData + #IoT + Citizen #Dat...
# ...                                                 ...
# 2498  RT @OpenSociety: How do you poll the public in...
# 2499  RT @GettyImages: .@PamGrossman11 on why powerf...
# 2500  RT @nytimes: Smart girls vs. bombs http://t.co...
# 2501          http://t.co/gf1IrBPyaZ #UVA #rollingstone
# 2502  RT @CJR: What are the larger threats to journa...
# 2503  RT @TIME: Here’s what happens when women decid...
# 2504  RT @wef: Why everyone in your company matters ...
# 2505  RT @TheFix: Why the death of sentimentality in...
# 2506  Bringing high-tech volunteers and nonprofits t...
# 2507  RT @wef: What's the future of social entrepren...
# 2508  RT @ddj_rr: This Just In: How Big Data is Chan...
# 2509  RT @VanityFair: Mellody Hobson’s life has shat...
# 2510  RT @FactTank: MT @GregSmith_Polls: Interesting...
# 2511  RT @dosomething: Empowering Girls To Create Th...
# 2512  RT @voxdotcom: Sleep is a luxury good: poor Am...
# 2513        Learning to See Data http://t.co/ERe729JF2d
# 2514             conquering fear http://t.co/m2gGLaNCc9
# 2515  RT @analyticbridge: 77 People Who Truly Have W...
# 2516  trends in how americans are engaging with news...
# 2517  recent events at UVA are rooted in pre-existin...
# 2518  "our culture has drawn an artificial line betw...
# 2519  studying the humanities is necessary - we need...
# 2520  a very intelligent, curious, and mature 12 yea...
# 2521  "explore something that counts," "develop new ...
# 2522  the risks vs. benefits of Facebook's hosting m...
# 2523  http://t.co/sdo3fRelE8 \n"the impact of one pe...
# 2524  Go UVA Men's Basketball! "Put the HOO in HOOPS...
# 2525  http://t.co/K85YbREV5p problems with greek lif...
# 2526  faculty can do more to discuss how #UVA commun...
# 2527  http://t.co/FXBQaNy3VG … - insightful video on...
#
# [2528 rows x 3 columns]

# %%
# retweets
retweets = megmfurr_tweets[megmfurr_tweets['text'].str.contains("RT")]
megmfurr_tweets[megmfurr_tweets['text'].str.contains("RT")]['text'].count() # 1,633
# Out:
# 1633

# %%
# tweets
tweets = megmfurr_tweets[megmfurr_tweets["text"].str.contains("RT")==False]
megmfurr_tweets[megmfurr_tweets["text"].str.contains("RT")==False]['text'].count() # 895
# Out:
# 895

# %%
# count by date in datetimes
retweets['id'].groupby(pandas.to_datetime(retweets['created_at']).dt.date).count().mean() # 2.86
# Out:
# 2.864912280701754

# %%
# count by date in datetimes
tweets['id'].groupby(pandas.to_datetime(tweets['created_at']).dt.date).count().mean()
# Out:
# 2.3126614987080103

# %%
# tweets about data science
words = ['Data Science','DataScience','datascience','Data Scientist','data science','data','data scientist','Data scientist']
pat = '|'.join(words)

datascience_tweets = megmfurr_tweets[megmfurr_tweets['text'].str.contains(pat)]
megmfurr_tweets[megmfurr_tweets['text'].str.contains(pat)]['text'].count()
# Out:
# 438

# %%
# data science retweets
datascience_tweets[datascience_tweets['text'].str.contains("RT")]['text'].count() # 322
# Out:
# 322

# %%
# data science tweets
datascience_tweets[datascience_tweets["text"].str.contains("RT")==False]['text'].count() # 895
# Out:
# 116
